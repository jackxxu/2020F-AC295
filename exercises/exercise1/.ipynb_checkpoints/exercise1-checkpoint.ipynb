# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 45px" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png"> APCOMP 295 Advanced Practical Data Science
# ## Homework 1 - Google Cloud Setup, Docker & Flask
#
#
#
# **Harvard University**<br/>
# **Fall 2020**<br/>
# **Instructors**: Pavlos Protopapas
#
#
# <hr style="height:2pt">

# %% [markdown]
# **Instructions**:
#
# - Each assignment is graded out of 5 points.
# - Submit this homework individually at Canvas.
#
# <hr style="height:2pt">

# %% [markdown]
#  We illustrated two very simple applications of containers during the demo in class and demonstrated them step by step. Now we should learn how to deploy a more complex application on the cloud. Real-world applications are often composed of many different components. Putting it altogether comprises many steps, which we walk you through below. It is not unusual that the tutorial instructions available on the internet, or in this case the assignment instructions, do not match exactly with what you will face - this is due to the quick development cycles of the libraries and user interfaces. Therefore, it is one of the learning objectives of this homework to learn how to become more comfortable with all the components, follow tutorials and how all connect together. You should use all resources available, including the class forum, or other forums and do not hesitate to ask the teaching staff.
#
# We will be using Google Cloud, and one of the goals of this assignment is to get you set up with Google Cloud.
#
# The final goal is to run your first Docker application with Flask on the cloud !
#
#
# ###  <font color=red>Remember to delete your virtual machines/clusters.</font>

# %% [markdown]
# ## Question 1: Create Accounts at Cloud Services (0.5 point)
#
# If you have not already done so, create accounts at the following cloud services we will be using in the course:
# - GitHub: www.github.com
# - Google Cloud: https://cloud.google.com/
#     (new users may be offered \$300 free trial - valid for 3 months -  See this for more  https://cloud.google.com/free/docs/gcp-free-tier )
# - DockerHub: https://hub.docker.com/
#
# #### Submit:
# 1. your username for GitHub and Google Cloud
# 2. a screenshot of the “profile” page of your GitHub account and the Google Cloud console
# 3. A screenshot of the  “Account settings” (top half) page of Docker Hub account.
#
# #### Example Submission:
# GitHub username = jackxxu
#
# ![image.png](https://ucc38cdba87f9faacb236bb35640.previews.dropboxusercontent.com/p/thumb/AA5VfeU_TokifT7FuC2dIcxMxA_HzTFD31iCq6_5XPe6djEtfSn4i-Rj0y8cJNRhArg1MxFR5S7a3PKztefWbm2O5zAN-7-xJFf2Wo6MDuObfqFndP_inOKY7nVAzEyEde5aptNfGNb1tJXVQvhoNFmCMDNkXvtBoJLeqNRoNoJd5ofXqzioVAhI71qoblqQd3JzwUWIMV-F565Om2RPQSomuk25AIw2u90j57W39x30w7a8a_Wsat1rQ5o7_KA8VUE9HnaWTL-C58tLKolYxsLREkuS21YTgsOSbjWl2dWKwpNjJdpWOytwKNKZp4_AsnTxlQASb8xjDE89rJtRf4F-o4_eOlPQ2kesz53R650RBctubZyHaYrq76cNbe4j4vuVg3FngHb-dduwbgw0blxq/p.png?fv_content=true&size_mode=5)

# %% [markdown]
# Google username = xix928@g.harvard.edu
#
# ![image.png](https://uc3cfc386dfcf85bbd0e30b88887.previews.dropboxusercontent.com/p/thumb/AA5vBBD3A1I77fImVyE1Cz-0k1mYwWOai_pnMax_VhPIhJT0RKtPKMomrsSx2rJtLwKTI0lJ6pom04HKUFjDg5HEoxUrMDaTMJ-cg2wPgHkBGZrtw5JI1YOxidfRMSimfBZOF_7vZfanmq3kGU7hoXn82Uua95SO3dEa4zh8eBlLu2M1dIYHy4hMfUq4d9GBlJ-JIZ_pwujBSvSTyPejww6spTtxY-Ikx3wr53Z_XFLt8_D7sEYrwFjzeS9Y6U9UArRKM0mtf-XijqPPpzNWFyub2xomXUUd6qFVWt18wSU5_iXwORG1LqSVaLkgx_OegKZh8EBxEyNe8MonybmXOTvQoWi7NfIUjTjWYYNe-rKvZJzjqeDQJQf1TsF2R08TQUfyFNhzW6-DgHSR3tuj3P5d/p.png?fv_content=true&size_mode=5)

# %% [markdown]
# Docker Hub:
#
# ![image.png](https://uc33e76be7a9d59ed7bfb6357e87.previews.dropboxusercontent.com/p/thumb/AA4-SG3ZcA8fxvqX63ERA6MoYU7dUYLu6RBAILlagp9rKceiWDzhrfB2ufG3kDWwiI3-9SfipAgdBFGILC_tK2kaJTznxismCTL_MoyQlDu5DYOSBrlaz48moGOyOLGwkXr1GqOHKE1BZbL-gvh323OY5tkBiKWiO6x1Z7547q_rWJgHDEv17SuZsGR7JTO5PDJ0fxK1edUVY4N5nhGvwK3xbUqmuRCvOHv9z62ihmgyFxcA2SL9N1tYY-yMW3Vu5tz8QYN0J7cDuxKyxffSOIr9uNx-zK934j_jlY8kMXYrkcw1Hxzt_8EBfg2kHep0t1_U2obRwmKLZdQaEKOwDHrDgtNh8ocV_-lDg1ZFwTkK1c43HxMlVZ8mXfVsGG9YRV2nOEByaTpfxxyRzOZM0vwT/p.png?size=2048x1536&size_mode=3)

# %% [markdown]
# ## Question 2: Create project on Google Cloud and Install Google cloud sdk (1 point)
#
# 1. Redeem your Google Cloud credit <font color=red> (You will need @g.harvard.edu email account, look for announcement on Ed before proceeding) </font>
# (this should create a billing account “AC295 Advance Practical Data Science”)
# Every project on Google cloud must be associated with a billing account.
#
# 2. Create a project on Google Cloud Console (top left -> “Select a project” -> New project  OR Dashboard -> Create Project) (if you are using .harvard you may select the .harvard organization).
# Project name: ac295-data-science
#
# 3. We will be using gcloud command line. Please follow the instructions on this page to install https://cloud.google.com/sdk/docs/quickstarts .
#
#
# #### Submit:
# 1. Screen shot of your new project
# 2. output from `gcloud config list`.
#
# #### Example Submission:
#
#
# ![image.png](https://uc8f4431317e3528a32d08f14c70.previews.dropboxusercontent.com/p/thumb/AA58EwH0pFJck6rdn28vk7Co6rKHrmejCCW-GfSp-1Zwx8z3C4PSf9Xp5vE6fXM2OgCb0b7efY5jZXZkR-unHRbk1nXailkIjWh2KGCHRw-f4Lw0Uate6Ckfl184PuqJso-1WHSEVYKdVSO19YH7aq-VEQaHC7z-S1tUBL_o8LQHVNhy1fdSQ8bywTLl562_ilV41N16w3QxDaMVX-V1LoFEYzDT8dyF7WyYPMN3bKgOctdi-k14wbk3skleRwoejE1kXcaJOGQ3UExJq80cm7RUELoGKh14Peg_PBTsHSfPkbJFReMQ3Hdr0yEi54IpYWI63z5dffT5EJhXRoXMqRRntnNHvSRTxtPWrk9Zyt4areW4l38yL8NsY3nBrmtTJxEDOdPzvNRcbE9IQUb8vVH7/p.png?size=2048x1536&size_mode=3)
#
# ```
# ➜  ~ gcloud config list
# [core]
# account = xix928@g.harvard.edu
# disable_usage_reporting = False
# project = spry-equator-289113
#
# Your active configuration is: [default]
# ```

# %% [markdown]
# ## Question 3: Set up SSH Keys (0.5 points)
#
# Many tasks in deploying apps to the cloud are done at the command line.  SSH is an essential tool for secure use of command line interfaces to remote systems.  SSH is also more convenient than password authentication once you’ve set it up.
# If you have not already done so, create a default SSH key on your main computer.
# Configure GitHub so that you can access your repositories using SSH.
#
# You can follow this tutorial:
# https://docs.github.com/en/github/authenticating-to-github/adding-a-new-ssh-key-to-your-github-account .Try to clone one of your repositories at the command line using the SSH interface.
#
#
# #### Submit:
# 1. a screenshot of your GitHub account showing at least one SSH key.
# 2. a screenshot of a terminal where you clone any repo with the SSH.
#
# Please note that it is always safe to share the public part of your SSH key as in submission 1, but you should **never** share a private RSA key with anyone!
#
# As an example of cloning by SSH, when I type:  ` git clone git@github.com:Harvard-IACS/2020F-AC295-private.git` this command works "by magic" on a computer that has one of the SSH keys I’ve configured on GitHub in the default key location `~/.ssh/id_rsa` (linux and Mac) or `C:\Users\<username>\.ssh\id_rsa` (Windows 10)
#
#
#
# #### Example Submission:
#
# ![image.png](https://ucaf45d3ec5743e60c04c67ff509.previews.dropboxusercontent.com/p/thumb/AA6wrAqmhqvWnMpQnqeL38ROMdFgNPEclxcgVd3PuBPzrEzhUUHeITDzWApGC9nCXzgAR5lQGXZLhclAHVKJiOGQvL0x8GapKawBzYSJywlg3qBvGfbXzVipxNLHChbaFIrzhtXhvyZduvi5HKNSUJZeDGlwoHgBkl_oB5zQ9Yujf_tMvAjaBUW0ucBpRID3BLkey3WMnsEpVtvCXGmgX_m0WwTOZu4LexCRgmVivLxVpRtFx-KTyz4c4FjFaL3Eoo9lUNqrojbGbJnVdQezMeYtGy7coAKk5FT1dr06hs75zO02TgLYkHBaE412myrpgB9m4zDcvYv9s9jBOhmIsaWazt0GzHYYJEe2Tgisj3--LVHnvdqpFpRFOg1oYa84WeUxJ8hhkTL8gJq0ccfje0dN/p.png?fv_content=true&size_mode=5)

# %% [markdown]
# ```
# ➜  apps git clone git@github.com:Harvard-IACS/2020F-AC295.git
# Cloning into '2020F-AC295'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 1745 (delta 15), reused 30 (delta 12), pack-reused 1694
# Receiving objects: 100% (1745/1745), 117.14 MiB | 24.57 MiB/s, done.
# Resolving deltas: 100% (962/962), done.
# Checking out files: 100% (511/511), done.
# ```

# %% [markdown]
# ## Flask
#
# Flask is a python based web framework. There are many others for e.g. Django, FastApi and next month will be more. We’ll stick to Flask in this course for many of the examples we will be doing. Though this class is not about teaching web developement, it is advisable to familiarize yourself with it.  In the next question we will be using a very simple flask app
# echo.py. We found the following video to be very instructive (aka a little long):
#
# Youtube  - https://youtu.be/Z1RJmh_OqeA

# %% [markdown]
# ## Question 4: Your First Docker App on Google Cloud (2 points)

# %% [markdown]
# We are going to create an echo service, which displays back what we send. We will do this on Google Cloud and also create a docker image on Google Cloud.
#
# Follow these steps (watch the demo video  https://youtu.be/aI6jTjwxWVI and replicate yourself):
# - Add a firewall rule  (the Compute Engine API must first be enabled before firewall rules can be created). If you do not see the firewall at the top of the pull down menu, look for "Networking".
# - Create a Virtual Machine on google cloud.
# - Install pip3, pandas, flask.
# - Copy echo.py and Dockerfile from https://github.com/bgweber/StartupDataScience/tree/master/containers/echo to the VM
# - Install Docker =>  https://docs.docker.com/engine/install/debian/
# - Create Dockerfile, Docker Image and run
# - **Must delete VM after you are done.**
#
#
#
#
# Submit
#
# (i) screenshot displaying a running VM on google cloud
#
# ![image.png](https://uced4d9f75054f2bafe534741322.previews.dropboxusercontent.com/p/thumb/AA7VWTLPE8Z8x6lsljG9SyRm9D0JmOD3gYqF6MBY0UDnXuUlgYQi2FWR2HYpvzDWONi3NB2VODgmEpBUogAHaL5LVaFpH2BxEinJY51UUfPXxKsENdC2JTEscLe4QtBkGMVibcVIPnjAw79qyqPsuGkmbLPG8eu85Oaiv6QdY6ySmMt1sPklwNIK09W-QFOXmO0frY05hQlnQ7I7ATIFBtGcpTwnXWmUeJ5YSbK_-bpTnphxm0QDowDrGf5HRnDQzHpV7c2civKJEdqmbfrZCFtzLYE9yQ53aSck3mPf2h1tynsZm9AxbfRImLlESPo2-kax_DH-a2RCwdMJiZ4nAYsCoH8t_r_XN6-eESho_zq-a3L8B3tGqRJ1SjTAQjYypqYJ3NJFB_vdAIBSf8mY-SJZ/p.png?fv_content=true&size_mode=5)
#
# (ii) screenshot of the browser where echo service displays results (with url)
#
# ![image.png](https://uc70c55002de8904b57bae117b76.previews.dropboxusercontent.com/p/thumb/AA5t5h_3qXHOKuxm3wODn-mvAOfWtWQLPhNiGKFAUQHYAEUetsuo-6h8FCY0CnN4A2OI1A7yj43pLEY2S-fBWe7j0mtHhVugznHDcjaRSmpJnxnEzXFiHeLkVpSEjpCgLzo3IKRL5vddNxjBWeN-RUk53lPEcIvTRrLVB4LqGCG0a-oEaHnCnmU_0ZT79QV_Tz__sdp1jQak132veEwYa0MyR6-7CWfRQVppjgQgf5FTqfXr9yKar5pf77qt-oyyRDdqGJH2SdnKJ4d_x5hD7SdR9NzaX0lFveANhxPKX90N64va8g7F4SanZwCbYjMkvkpV3X3SXdXek6sCmznlmLNPNX2hQ7xDZBNcLXrs3adf0AjUCo0rQ98gQGEK8XziaHpu5FHi_jJoWEsvSX5BBvb4/p.png?size=2048x1536&size_mode=3)
#
# (iii) screenshot of docker container running and docker images.
#
# ![image.png](https://uc5d8565cf7b708a3440686dd69e.previews.dropboxusercontent.com/p/thumb/AA4q7o8WHlDBEXWUJwr4vbaae6rCYLZQSuuQ0n3cUY7i6v-z0xU0wlZngMZloovF6ZnyDMbVhsKcLxgRgjgIyVk8zOzgGfqhEqj2o1_FJoCivLmqyaIs184E4F3dk5gnJlIhEh4s0yJT-U1yIlNZZsldUKUbyODRXconauQSBF9IPL2QKAGHWC_snxh5jK6-bJCymqUTESLZygHlzyEHB2vAyEMvYFjcJdmBOrkKI23rH1dgfAfOFnPV2EtWmjU3PuJ6GYDEemB6zqMpv7dUJ_rxDMwEuZs9ciSZJ4H2hb_ASbDjFBk9P96RsAWhFGe1BpxUHl8y3_1UqEpsHJJzRBAI55fo15fEbV4Lrk2ngB8qENSoYkW3wJIQakge-G5l0YWeRqizvAenGfgZE88RBGN9/p.png?fv_content=true&size_mode=5)
#
#
# (iv) log/notes of commands used.
#
# ```
# xiaosongxu@ac295instance:~/StartupDataScience/containers/echo$ history
#     1  ls
#     2  sudo apt-get update
#     3  sudo apt install python3-pip
#     4  pip3 --version
#     5  pip install pandas numpy flask
#     6  pip3 install pandas numpy flask
#     7  pip3 install Flask
#     8  git
#     9  sudo apt-get install git
#    10  git clone https://github.com/bgweber/StartupDataScience.git
#    11  cd StartupDataScience/containers/echo/
#    12  ls
#    13  sudo apt-get install     apt-transport-https     ca-certificates     curl     gnupg-agent     software-properties-common
#    14  curl -fsSL https://download.docker.com/linux/debian/gpg | sudo apt-key add -
#    15  sudo apt-key fingerprint 0EBFCD88
#    16  sudo add-apt-repository    "deb [arch=amd64] https://download.docker.com/linux/debian \
#    $(lsb_release -cs) \
#    stable"
#    17  sudo apt-get update
#    18  sudo apt-get install docker-ce docker-ce-cli containerd.io
#    19  sudo docker run hello-world
#    20  docker image build -t 'echo-service'
#    21  docker image build -t 'echo-service' .
#    22  sudo docker image build -t 'echo-service' .
#    23  docker image ls
#    24  sudo docker image ls
#    25  sudo docker run -d -p 80:5000 echo-service
#    26  sudo docker ps
# ```
#
#
# Also, don’t hesitate to post questions on the Ed class discussion board.  One of your classmates or the teaching staff can help.

# %% [markdown]
# ## Question 5: Echo Translation  (1 point)

# %% [markdown]
# Now we learn all the mechanics, lets create a similar system as in Question 4 but this time the system should display the input text translated to a language of your choice.
#
# **Submit:** Modified echo.py i.e. copy paste the code in a cell below (Please use cell -> Raw NBConvert)  and
#
# ```python
# import flask
# from googletrans import Translator
#
# app = flask.Flask(__name__)
#
# translator = Translator()
#
# # define a predict function as an endpoint
# @app.route("/predict", methods=["GET","POST"])
# def predict():
#     data = {"success": False}
#
#     # get the request parameters
#     params = flask.request.json
#     if (params == None):
#         params = flask.request.args
#
#     # if parameters are found, echo the msg parameter
#     if (params != None):
#         data["response"] = params.get("msg")
#         data["success"] = True
#         data["language"] = 'French'
#         data["translated_text"] = translator.translate(params.get("msg"), src='en', dest='fr').text
#
#
#     # return a response in json format
#     return flask.jsonify(data)
#
# # start the flask app, allow remote connections
# app.run(host='0.0.0.0')
#
# ```
#
#
# (i) screenshot displaying a running VM on google cloud
#
# ![image.png](https://uced4d9f75054f2bafe534741322.previews.dropboxusercontent.com/p/thumb/AA7VWTLPE8Z8x6lsljG9SyRm9D0JmOD3gYqF6MBY0UDnXuUlgYQi2FWR2HYpvzDWONi3NB2VODgmEpBUogAHaL5LVaFpH2BxEinJY51UUfPXxKsENdC2JTEscLe4QtBkGMVibcVIPnjAw79qyqPsuGkmbLPG8eu85Oaiv6QdY6ySmMt1sPklwNIK09W-QFOXmO0frY05hQlnQ7I7ATIFBtGcpTwnXWmUeJ5YSbK_-bpTnphxm0QDowDrGf5HRnDQzHpV7c2civKJEdqmbfrZCFtzLYE9yQ53aSck3mPf2h1tynsZm9AxbfRImLlESPo2-kax_DH-a2RCwdMJiZ4nAYsCoH8t_r_XN6-eESho_zq-a3L8B3tGqRJ1SjTAQjYypqYJ3NJFB_vdAIBSf8mY-SJZ/p.png?fv_content=true&size_mode=5)
#
#
# (ii) screenshot of the browser where echo service displays results (with url)
#
# ![image.png](https://uc5d3249012b4a4651c6f2555668.previews.dropboxusercontent.com/p/thumb/AA46wdx86AWGinE_Ml7CumQB458AphCb_uOx9s6OU2AsVyQj9E6tD5h_mHXEGBQfbFERfJSY0KmqA_F4Ig_FqOHlQ7bNFQRILq1CTi4AKzqW99wW9ScvTvTmBACe_sbhuWVxDLgajv-xURvS4b7GA6-6F1ChQdBejkp6v6yGw3cjTySrogWyo3xes5j3mxbVFQls57qjIM-KmBe-18jlgnKpAsxsktmnfPL-ObTZhNMz-yiFLOFwgbKPd4_n_4GDlE_6cV-8RkeKKtKB5TYM1uU5x-SXs8Kc-EPLVLcRyVGiaHgSu8r8QjR6WBiuUvvzibYy4Etd46Q054ZrTtWdgL6jpwIUyDFDPUysQWMgCE-3M6NQArBE3_VtGc_ZsVOx0gyD47W07Vl-aOisRWjik1OF/p.png?fv_content=true&size_mode=5)
#
# (iii) screenshot of docker container running and docker images.
# ![image.png](https://ucf4c2e7a57c8bb82e76c275c16b.previews.dropboxusercontent.com/p/thumb/AA7lvS3eWN_nHSMBbKed2sRkSc9U2fCbBzWruZSkjqOrfU1HVE5dtnXax5EnB3aJsKmZVPWE8NyLXOkJf4nfQGyvX_duqop_OHGDSrlF0kRJpgr2Oo4D7ek60ril_5vGuMo2TUsQAkAPa55FFVcUfIzOm-yEFbrYBSg7-MrRuDC9rmCQULTU2w2_TqWtJhi4vXaIwyAbzvMh_uAtgNnzM5gbY38yqA1jCHKLa9yOhVUYuituQ84vqqeYcg0b9FBwkKTbrXrIFw8i4uS8CMcNOy_kVqtQ_bX1spHDLBnBjLyTnqL8RLiuwGR0qII6LHVu0DsqW-DWMQYruKZR9QbLz90NSrmBAlYGptjFYPCxQ2NsFw749yhtN2SQfrTBeWx5i1zpKXJenr5lB6-pG0xgb4xI/p.png?fv_content=true&size_mode=5)
#
# (iv) log/notes of commands used.
#
# ```
#    28  sudo docker ps
#    29  sudo docker images
#    30  sudo pip3 install googletrans
#    31  sudo apt-get install vim
#    32  vim echo.py
#    33  docker stop $(docker ps -aq)
#    34  sudo docker stop $(docker ps -aq)
#    35  sudo docker stop $(sudo docker ps -aq)
#    36  docker rm $(docker ps -aq)
#    37  sudo docker rm $(sudo docker ps -aq)
#    38  docker rmi $(docker images -q)
#    39  sudo docker rmi $(sudo docker images -q)
#    40  sudo docker image build -t 'echo-service' .
#    41* vim
#    42  sudo docker ps
#    43  sudo docker log
#    44  sudo docker logs
#    45  vim echo.py
#    46  sudo docker rm $(sudo docker ps -aq)
#    47  sudo docker rmi $(sudo docker images -q)
#    48  sudo docker image build -t 'echo-service' .
#    49  sudo docker run -d -p 80:5000 echo-service
#    50  sudo docker ps
#    51  vim Dockerfile
#    52  sudo docker rmi $(sudo docker images -q)
#    53  sudo docker rm $(sudo docker ps -aq)
#    54  sudo docker rmi $(sudo docker images -q)
#    55  sudo docker image build -t 'echo-service' .
#    56  sudo docker run -d -p 80:5000 echo-service
#    57  docker ps
#    58  sudo docker ps
#    59  sudo docker image ls
# ```
#
# **Hints:**
# - Make sure you can display characters that are not ASCII. Try different languages.
# - Hint: `pip install googletrans`

# %% [markdown]
# ###  <font color=red>Remember to delete your virtual machines/clusters.</font>
